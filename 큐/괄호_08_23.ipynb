# %%
#https://www.acmicpc.net/problem/9012
"""
괄호 문자열(Parenthesis String, PS)은 두 개의 괄호 기호인 ‘(’ 와 ‘)’ 만으로 구성되어 있는 문자열이다. 그 중에서 괄호의 모양이 바르게 구성된 문자열을 올바른 괄호 문자열(Valid PS, VPS)이라고 부른다. 한 쌍의 괄호 기호로 된 “( )” 문자열은 기본 VPS 이라고 부른다. 만일 x 가 VPS 라면 이것을 하나의 괄호에 넣은 새로운 문자열 “(x)”도 VPS 가 된다. 그리고 두 VPS x 와 y를 접합(concatenation)시킨 새로운 문자열 xy도 VPS 가 된다. 
예를 들어 “(())()”와 “((()))” 는 VPS 이지만 “(()(”, “(())()))” , 그리고 “(()” 는 모두 VPS 가 아닌 문자열이다. 
여러분은 입력으로 주어진 괄호 문자열이 VPS 인지 아닌지를 판단해서 그 결과를 YES 와 NO 로 나타내어야 한다. 
입력 데이터는 표준 입력을 사용한다. 입력은 T개의 테스트 데이터로 주어진다. 입력의 첫 번째 줄에는 입력 데이터의 수를 나타내는 정수 T가 주어진다.
 각 테스트 데이터의 첫째 줄에는 괄호 문자열이 한 줄에 주어진다. 하나의 괄호 문자열의 길이는 2 이상 50 이하이다. 

알고리즘 설명
1.일단 데이터를 넣는 거 부터 조금의 시간 단축과 한개의 원소씩 저장하기 위해 map과 lambda를 사용하여 시간을 줄이고
  list형식으로 담아 저장한다. 이렇게 되면 2차원 배열이 생성되고 1차원의 배열에는 입력받은 괄호 문자열이 한개의 문자씩으로 분리되어 저장이 된다

2. 리스트의 저장된 문자들을 가져온다. 그냥 for문을 돌려 한개씩 받아오고 '(' 이면 열린것이니 count를 1 증가시키고 ')'이면 닫힌것이니 count를 1 감소시킨다.
   근데 문제가 ()) 이런 경우처럼 이런것은 괄호가 제대로 성립하지 않는다. 근데 저런 경우는 count가 마이너스인 경우이기 때문에 count가 마이너스로 되면
   반복을 중지한다.

3. 맨 마지막에는 출력 부분인데 count가 0이면 YES를 0이 아니면 NO를 출력하면 된다.

큐와 스택을 이용해 푸는거로 지정이 되어있어서 추가로 작성한다.
큐 구조 기반으로 자료를 저장한다. 그 이유는 맨 처음의 들어간 값으로 yes인지 no인지 결정해야하기 때문이다.
append()를 이용해 put를 해주고 pop(0)을 이용해 get을 한다.

"""
input_num = int(input())
input_list = []
for i in range(input_num):
    input_str = input()
    input_list.append(list(map(lambda x: x, input_str)))

for i in input_list:
    count = 0
    for j in i:
        if count < 0:
            break
        elif j == '(':
            count += 1
        elif j == ')':
            count -= 1
    if count != 0:
        print("NO")
    else:
        print("YES")
# Out:
# 6
# (())())
# (((()())()
# (()())((()))
# ((()()(()))(((())))()
# ()()()()(()()())()
# (()((())()(
# NO
# NO
# YES
# NO
# YES
# NO

# %% [markdown]
# # 큐 구조로 만든 알고리즘

# %%
input_num = int(input())
input_list = []
for i in range(input_num):
    input_str = input()
    input_list.append(list(map(lambda x: x, input_str)))

for i in range(input_num):
    count = 0
    data = input_list.pop(0)
    for j in data:
        if count < 0:
            break
        elif j == '(':ii
            count += 1
        elif j == ')':
            count -= 1
    if count != 0:
        print("NO")
    else:
        print("YES")
# Out:
# 6
# (())())
# (((()())()
# (()())((()))
# ((()()(()))(((())))()
# ()()()()(()()())()
# (()((())()(
# NO
# NO
# YES
# NO
# YES
# NO
